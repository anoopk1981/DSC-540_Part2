# %%
from IPython.display import display
display({'text/html': '<h1>Topic4 Assignment - Part 2</h1>', 'text/plain': 'Topic4 Assignment - Part 2'}, raw=True)
display({'text/html': '<h1>Anoop Korappath</h1>', 'text/plain': 'Anoop Korappath'}, raw=True)
display({'text/html': '<h1>11/22/2021</h1>', 'text/plain': '11/22/2021'}, raw=True)
# Out:
# Topic4 Assignment - Part 2
# Anoop Korappath
# 11/22/2021

# %% [markdown]
# #### a) Generate 50 data points from this function in the range [– 3, 3]

# %%
import numpy as np
import matplotlib.pyplot as plt

data=np.linspace(-3, 3, 50)
sig_data=np.sinc(data)

plt.plot(data, sig_data, marker = "x")
plt.title("sinc()")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %% [markdown]
# #### b) Add Gaussian noise to the data.

# %%
noise_data = np.random.normal(0,0.5,50)
with_noise_data=sig_data+noise_data

plt.plot(data,with_noise_data )
plt.title("sinc() with noise")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %% [markdown]
# #### c) Train an SVM regressor with the data generated in (a). Define (and explain) suitable parameters required for training the regressor.

# %%
from sklearn.svm import SVR, SVC
regressor = SVR(kernel = 'rbf',gamma = 'scale')
clf = regressor.fit(with_noise_data.reshape(-1,1),sig_data.reshape(-1,1))
# Out:
# C:\Users\Anoops\PycharmProjects\pythonProject\venv\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %% [markdown]
# ###### In the above SVR function I am using the RBF(Radial Basis Function) kernel.
# ###### RBF is the default kernel used within the sklearn’s SVM classification algorithm
# ###### Other options includes {‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’}
# ###### The gamma is set to 'scale' by default. It uses 1 / (n_features * X.var()) as value of gamma

# %% [markdown]
# #### d) Describe the functionality of the regressor.
#
# ###### Support Vector Regression (SVR) uses the same principle as SVM, but for regression problems.
# ###### The problem of regression is to find a function that approximates mapping from an input domain to real numbers on the basis of a training sample.
# ###### We can think of Support Vector Regression as the counterpart of SVM for regression problems. SVR acknowledges the presence of non-linearity in the data and provides a proficient prediction model.
# ###### Consider these two red lines as the decision boundary and the green line as the hyperplane. Our objective, when we are moving on with SVR, is to basically consider the points that are within the decision boundary line. Our best fit line is the hyperplane that has a maximum number of points.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
image = mpimg.imread("C:\\Users\\Anoops\\Downloads\\1.jpg")
plt.imshow(image)
plt.show()

# %% [markdown]
# ###### The first thing that we’ll understand is what is the decision boundary (the danger red line above!). Consider these lines as being at any distance, say ‘a’, from the hyperplane. So, these are the lines that we draw at distance ‘+a’ and ‘-a’ from the hyperplane. This ‘a’ in the text is basically referred to as epsilon.
# ###### Assuming that the equation of the hyperplane is as follows:
# Y = wx+b (equation of hyperplane)
# ###### Then the equations of decision boundary become:
# wx+b= +a <br>
# wx+b= -a
# ###### Thus, any hyperplane that satisfies our SVR should satisfy:
# -a < Y- wx+b < +a
# ###### Our main aim here is to decide a decision boundary at ‘a’ distance from the original hyperplane such that data points closest to the hyperplane or the support vectors are within that boundary line.
# ###### Hence, we are going to take only those points that are within the decision boundary and have the least error rate, or are within the Margin of Tolerance. This gives us a better fitting model.

# %% [markdown]
# #### e) Discuss the potential use of the regressor and quantify its accuracy.
#
# ######  Sugiyama and Müller (2002) use the sinc kernel, among other choices, to demonstrate that their generalisation bound for regression is stable with respect to kernel choice. It is perhaps less well known that, by virtue of the following three established results, the sinc kernel also lends itself to the regularised support vector classification setting.
# ###### SVM classification machine learning problem that can also be tackled in the context of signal theory. The interconnection between Paley–Wiener spaces and the sinc kernel has been exploited to form an explicit relationship between the information model and the sinc kernel hyper-parameter. By employing some recent work on sequency analysis, it has been shown that the nature of the model can be discerned. Driven by this theory, a finite hyper-parameter search space was realised. Moreover, by introducing further assumptions, the researchers have shown that the compromise between computational effort and search space sparseness can be managed sensibly. Finally, the approach achieves the best results so far on the much-studied AVIRIS remote-sensing data set.
